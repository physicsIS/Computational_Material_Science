# %%
from funciones import generate_scf_inputs

# %%
generate_scf_inputs('joint_simulation.traj','pw_inicial.in',[44,45,46,47,40],[804])
# Out:
# [OK] Generated: full_frame_804.in
# [OK] Generated: selected_frame_804.in
# [OK] Generated: remaining_frame_804.in

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scienceplots 
import numpy as np
plt.style.use(["science","notebook", "grid"])

# %%
df = pd.read_csv('outputs/energias.dat')

# %%
y = df['energia']

fig, ax = plt.subplots(1,1, figsize = (12,8))

ax.plot(y)
fig.savefig("energia.png")
